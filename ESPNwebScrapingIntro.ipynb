# %% [markdown]
# # Building a web scraper for ESPNscrum using BeautifulSoup4

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Thankfully the website is built so that the url corresponds to data queries

# %%
# TODO: write function that returns url 
page = 1
url = ('http://stats.espnscrum.com/statsguru/'
        +'rugby'
        +'/stats/index.html?'
        +'class=1;'
        +'filter=advanced;'
        +'orderby=date;'
        +'page='+page
        +'size=200;'
        +'spanmax2=1+Apr+2020;'
        +'spanmin2=22+May+1987;'
        +'spanval2=span;'
        +'team=8;'
        +'template=results;'
        +'type=team;'
        +'view=match'
      )
print(url)

response = requests.get(url)
print('.get() status: {response.status_code}')
page = response.text
del response
# Out:
# http://stats.espnscrum.com/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=date;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match
# .get() status: {response.status_code}

# %%
soup = BeautifulSoup(page, "html5lib")

# %%
# search for <table class='engineTable'> [1]

match_list = (soup.find_all('table', class_='engineTable'))[1]

# %%
match_list
# Out:
# <table class="engineTable">
# <caption>Match list</caption>
# <thead>
#  <tr class="headlinks">
#   <th class="left" nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=team;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by team name">Team</a></th>
#   <th class="left" nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=result;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by result of match">Result</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=for;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total points scored">For</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=against;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total points conceded">Aga</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=difference;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by points difference">Diff</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=tries;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total tries scored">Tries</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=conversions;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total conversions scored">Conv</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=penalty_goals;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total penalty goals scored">Pens</a></th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=drop_goals;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by total drop goals scored">Drop</a></th>
#   <th nowrap=""></th>
#   <th class="left" nowrap="" title="opposition team name">Opposition</th>
#   <th class="left" nowrap="" title="ground played on">Ground</th>
#   <th nowrap=""><a class="black-link" href="/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=date;orderbyad=reverse;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match" title="sort by match date">Match Date<img alt="Ascending" border="0" height="10" src="/navigation/engine-nav/up.gif" style="vertical-align: middle;" width="10"/></a></th>
#   <th></th>
#  </tr>
# </thead>
# <tbody>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>70</td>
#   <td>6</td>
#   <td>+64</td>
#   <td>12</td>
#   <td>8</td>
#   <td>2</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Italy</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16155.html">Auckland</a></td>
#   <td nowrap=""><b>22 May 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd1', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>74</td>
#   <td>13</td>
#   <td>+61</td>
#   <td>12</td>
#   <td>10</td>
#   <td>2</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Fiji</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16149.html">Christchurch</a></td>
#   <td nowrap=""><b>27 May 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd2', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>46</td>
#   <td>15</td>
#   <td>+31</td>
#   <td>6</td>
#   <td>2</td>
#   <td>6</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Argentina</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16134.html">Wellington</a></td>
#   <td nowrap=""><b>1 Jun 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd3', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>30</td>
#   <td>3</td>
#   <td>+27</td>
#   <td>2</td>
#   <td>2</td>
#   <td>6</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Scotland</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16149.html">Christchurch</a></td>
#   <td nowrap=""><b>6 Jun 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd4', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>49</td>
#   <td>6</td>
#   <td>+43</td>
#   <td>8</td>
#   <td>7</td>
#   <td>1</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Wales</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16340.html">Brisbane</a></td>
#   <td nowrap=""><b>14 Jun 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd5', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>29</td>
#   <td>9</td>
#   <td>+20</td>
#   <td>3</td>
#   <td>1</td>
#   <td>4</td>
#   <td>1</td>
#   <td></td>
#   <td class="left" nowrap="">v France</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16155.html">Auckland</a></td>
#   <td nowrap=""><b>20 Jun 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd6', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>30</td>
#   <td>16</td>
#   <td>+14</td>
#   <td>4</td>
#   <td>1</td>
#   <td>3</td>
#   <td>1</td>
#   <td></td>
#   <td class="left" nowrap="">v Australia</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16551.html">Sydney</a></td>
#   <td nowrap=""><b>25 Jul 1987</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd7', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>52</td>
#   <td>3</td>
#   <td>+49</td>
#   <td>10</td>
#   <td>6</td>
#   <td>0</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Wales</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16149.html">Christchurch</a></td>
#   <td nowrap=""><b>28 May 1988</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd8', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>54</td>
#   <td>9</td>
#   <td>+45</td>
#   <td>8</td>
#   <td>8</td>
#   <td>2</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Wales</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16155.html">Auckland</a></td>
#   <td nowrap=""><b>11 Jun 1988</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd9', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>32</td>
#   <td>7</td>
#   <td>+25</td>
#   <td>5</td>
#   <td>3</td>
#   <td>2</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Australia</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16551.html">Sydney</a></td>
#   <td nowrap=""><b>3 Jul 1988</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-d
td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v France</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16701.html">Stade de France</a></td>
#   <td nowrap=""><b>18 Nov 2006</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd191', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>45</td>
#   <td>10</td>
#   <td>+35</td>
#   <td>5</td>
#   <td>4</td>
#   <td>4</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Wales</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16727.html">Millennium Stadium</a></td>
#   <td nowrap=""><b>25 Nov 2006</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd192', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>42</td>
#   <td>11</td>
#   <td>+31</td>
#   <td>5</td>
#   <td>4</td>
#   <td>3</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v France</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16155.html">Auckland</a></td>
#   <td nowrap=""><b>2 Jun 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd193', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>61</td>
#   <td>10</td>
#   <td>+51</td>
#   <td>9</td>
#   <td>5</td>
#   <td>2</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v France</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16744.html">Wellington</a></td>
#   <td nowrap=""><b>9 Jun 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd194', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>64</td>
#   <td>13</td>
#   <td>+51</td>
#   <td>10</td>
#   <td>7</td>
#   <td>0</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Canada</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16791.html">Hamilton</a></td>
#   <td nowrap=""><b>16 Jun 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd195', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>26</td>
#   <td>21</td>
#   <td>+5</td>
#   <td>2</td>
#   <td>2</td>
#   <td>3</td>
#   <td>1</td>
#   <td></td>
#   <td class="left" nowrap="">v South Africa</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16294.html">Durban</a></td>
#   <td nowrap=""><b>23 Jun 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd196', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">lost</td>
#   <td>15</td>
#   <td>20</td>
#   <td nowrap="">-5</td>
#   <td>2</td>
#   <td>1</td>
#   <td>1</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Australia</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16693.html">Melbourne</a></td>
#   <td nowrap=""><b>30 Jun 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd197', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>33</td>
#   <td>6</td>
#   <td>+27</td>
#   <td>3</td>
#   <td>3</td>
#   <td>4</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v South Africa</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16149.html">Christchurch</a></td>
#   <td nowrap=""><b>14 Jul 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd198', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>26</td>
#   <td>12</td>
#   <td>+14</td>
#   <td>1</td>
#   <td>0</td>
#   <td>7</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Australia</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16155.html">Auckland</a></td>
#   <td nowrap=""><b>21 Jul 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd199', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
#  <tr class="data1">
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/team/8.html">New Zealand</a></td>
#   <td class="left">won</td>
#   <td>76</td>
#   <td>14</td>
#   <td>+62</td>
#   <td>11</td>
#   <td>9</td>
#   <td>1</td>
#   <td>0</td>
#   <td></td>
#   <td class="left" nowrap="">v Italy</td>
#   <td class="left" nowrap=""><a class="data-link" href="/statsguru/rugby/ground/16213.html">Marseille</a></td>
#   <td nowrap=""><b>8 Sep 2007</b></td>
#   <td class="query"><a href="javascript:void(0)" onmouseout="menuLayers.hide()" onmouseover="menuLayers.show('engine-dd200', event); window.status='investigate this query'; return true"><img alt="investigate this query" border="0" height="14" src="/navigation/engine-nav/drilldown.gif" width="10"/></a></td>
#  </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Get headers

# %%
# TODO: Write function that pulls headers

headers = []
headers = tuple(elem.text for elem in match_list.find('thead').find('tr').find_all('th'))
headers
# Out:
# ('Team',
#  'Result',
#  'For',
#  'Aga',
#  'Diff',
#  'Tries',
#  'Conv',
#  'Pens',
#  'Drop',
#  '',
#  'Opposition',
#  'Ground',
#  'Match Date',
#  '')

# %% [markdown]
# ## Get data for one row

# %%
# TODO: write function that gets data from table as list of tuples

row = []
row = tuple(match.findNext().text for match in match_list.find('tbody').findNext('tr').find_all('td'))
row
# Out:
# ('New Zealand',
#  '70',
#  '6',
#  '+64',
#  '12',
#  '8',
#  '2',
#  '0',
#  '',
#  'v Italy',
#  'Auckland',
#  'Auckland',
#  '22 May 1987',
#  '')

# %% [markdown]
# # Let's put it all together
# Thankfully the website is built in such a way that html queries get us to the page we need.

# %%
# URL creator

def getESPNScrumUrl(team, page, start_date = '22+May+1987', end_date = '1+Apr+2020', 
                    sport = 'rugby', sort_filter = 'advanced', order_by='date',
                    template = 'results', type_ = 'team', view = 'match'):
    '''
    Short 
    '''
    
    team = str(team)
    page = str(page)

    url = ('http://stats.espnscrum.com/statsguru/'
            +sport
            +'/stats/index.html?'
            +'class=1;'
            +'filter='+sort_filter+';'
            +'orderby='+order_by+';'
            +'page='+page+';'
            +'size=200;'
            +'spanmax2='+end_date+';'
            +'spanmin2='+start_date+';'
            +'spanval2=span;'
            +'team='+team+';'
            +'template='+template+';'
            +'type='+type_+';'
            +'view='+view
          )
    print(' '+url)
    return url

# %%
getESPNScrumUrl(team=8,page=1)
# Out:
#  http://stats.espnscrum.com/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=date;page=1;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match
# 'http://stats.espnscrum.com/statsguru/rugby/stats/index.html?class=1;filter=advanced;orderby=date;page=1;size=200;spanmax2=1+Apr+2020;spanmin2=22+May+1987;spanval2=span;team=8;template=results;type=team;view=match'

# %%
# TODO: create dictionary of teams to team_number
teams = {
    '1' : 'England',
    '2' : 'Scotland',
    '3' : 'Ireland',
    '4' : 'Wales',
    '5' : 'South Africa',
    '6' : 'Australia',
    '7' : 'Germany',
    '8' : 'New Zealand',
    '9' : 'France',
    '10': 'Argentina',
    '11': 'United States of America',
    '12': 'Romania',
    '13': 'Poland',
    '14': 'Fiji',
    '15': 'Samoa',
    '16': 'Tonga',
    #'17': 'Sri Lanka',
    '18': 'Spain',
    #'19': None,
    '20': 'Italy',
    '21': 'Belgium',
    '22': 'Netherlands',
    '23': 'Japan',
    '24': 'Morocco',
    '25': 'Canada',
    '26': 'Hong Kong',
    '27': 'Portugal',
    '28': 'Chile',
    '29': 'Uruguay',
    '30': 'Denmark',
    '31': 'Sweden',
    '56': 'Switzerland',
    '81': 'Georgia',
    '82': 'Namibia',
    '32': 'British and Irish Lions',
}
len(teams)
# Out:
# 33

# %%
response = requests.get(url)
print('.get() status: {response.status_code}')
page = response.text
del response

# match_list = BeautifulSoup(page, "html5lib").find_all('table', class_='engineTable')[1]

# TODO: pull headers function

# TODO: write function to get rows

# %%
rows = [row for row in match_list.find('tbody').find_all('tr')]  # tr tag is for rows

# %%
for row in rows[1:6]:
    items = row.find_all('td')
    link = items[0].find('a')
    title, url = link.text, link['href']
    movies[title] = [url] + [i.text for i in items]
